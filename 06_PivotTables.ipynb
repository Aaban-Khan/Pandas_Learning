# %%
import pandas as pd 
import numpy as np

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    950     50   John  January      Q1
# 1  2023-01-02       B   West    180     96   Mary  January      Q1
# 2  2023-01-03       C  North    868     38    Bob  January      Q1
# 3  2023-01-04       D  South    209     93  Alice  January      Q1
# 4  2023-01-05       A   East    512     68   John  January      Q1
# 5  2023-01-06       B   West    383     50   Mary  January      Q1
# 6  2023-01-07       C  North    598     41    Bob  January      Q1
# 7  2023-01-08       D  South    210     43  Alice  January      Q1
# 8  2023-01-09       A   East    707     42   John  January      Q1
# 9  2023-01-10       B   West    713     51   Mary  January      Q1
# 10 2023-01-11       C  North    101     21    Bob  January      Q1
# 11 2023-01-12       D  South    768     86  Alice  January      Q1
# 12 2023-01-13       A   East    768     99   John  January      Q1
# 13 2023-01-14       B   West    841     79   Mary  January      Q1
# 14 2023-01-15       C  North    543     48    Bob  January      Q1
# 15 2023-01-16       D  South    261     49  Alice  January      Q1
# 16 2023-01-17       A   East    107     32   John  January      Q1
# 17 2023-01-18       B   West    610     43   Mary  January      Q1
# 18 2023-01-19       C  North    501     23    Bob  January      Q1
# 19 2023-01-20       D  South    206     34  Alice  January      Q1

# %%
pd.pivot_table(df, values="Sales",index="Region",columns="Product", aggfunc="median")
# Out:
# Product      A      B      C      D
# Region
# East     707.0    NaN    NaN    NaN
# North      NaN    NaN  543.0    NaN
# South      NaN    NaN    NaN  210.0
# West       NaN  610.0    NaN    NaN

# %%
pd.pivot_table(df, values=["Sales","Units"], index="Region", columns="Product")
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     608.8    NaN    NaN    NaN  58.2   NaN   NaN   NaN
# North      NaN    NaN  522.2    NaN   NaN   NaN  34.2   NaN
# South      NaN    NaN    NaN  330.8   NaN   NaN   NaN  61.0
# West       NaN  545.4    NaN    NaN   NaN  63.8   NaN   NaN

# %% [markdown]
# Cross Tabs

# %%
pd.crosstab(df["Region"],df["Product"])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
