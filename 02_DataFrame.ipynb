# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
columns= ["Name", "Age", "City", "Salary"]
df2 = pd.DataFrame(data_list, columns=columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# Selection and Indexing of Columns

# %%
df2[["Name", "City"]]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# Creating a new column

# %%
df2["Designation"]=["Dr","Eng", "Unemployed", "Jobless"]
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000          Dr
# 1   Anna   34     Paris   70000         Eng
# 2  Peter   29    Berlin   62000  Unemployed
# 3  Linda   42    London   85000     Jobless

# %% [markdown]
# Removing Columns

# %%
df2.drop(["City","Designation"], axis=1) # use "Inplace=True" if you want to remove it permanently
# Out:
#     Name  Age  Salary
# 0   John   28   65000
# 1   Anna   34   70000
# 2  Peter   29   62000
# 3  Linda   42   85000

# %%
df2.drop(0, axis=0)
# Out:
#     Name  Age    City  Salary Designation
# 1   Anna   34   Paris   70000         Eng
# 2  Peter   29  Berlin   62000  Unemployed
# 3  Linda   42  London   85000     Jobless

# %% [markdown]
# Selecting Rows

# %%
df2.loc[[0,1]]
# Out:
#    Name  Age      City  Salary Designation
# 0  John   28  New York   65000          Dr
# 1  Anna   34     Paris   70000         Eng

# %%
df2.iloc[3]
# Out:
# Name             Linda
# Age                 42
# City            London
# Salary           85000
# Designation    Jobless
# Name: 3, dtype: object

# %% [markdown]
# Selecting Subsets of Rows and Columns

# %%
df2.loc[[0,1]][["Name", "Salary"]]
# Out:
#    Name  Salary
# 0  John   65000
# 1  Anna   70000

# %% [markdown]
# conditional data

# %%
#I only want to see those people whose age is above 30

# %%
df2[df2["Age"] > 30]
# Out:
#     Name  Age    City  Salary Designation
# 1   Anna   34   Paris   70000         Eng
# 3  Linda   42  London   85000     Jobless

# %%
df2[(df2["Age"]>30) & (df2["Salary"]>70000)]
# Out:
#     Name  Age    City  Salary Designation
# 3  Linda   42  London   85000     Jobless
